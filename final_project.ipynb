# %%
import pandas as pd
import seaborn as sns
url = 'https://github.com/AdarSaban/olypmic_project/raw/main/my_porject_csv.csv'
our_data = pd.read_csv(url)
our_data
# Out:
#         ID                      Name Sex   Age  Height  Weight  \
# 0        1                 A Dijiang   M  24.0   180.0    80.0
# 1        2                  A Lamusi   M  23.0   170.0    60.0
# 2        3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3        4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4        5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...    ...                       ...  ..   ...     ...     ...
# 3501  1996            Ali Al-Khalifa   M   NaN   175.0    65.0
# 3502  1997         Salman Al-Khalifa   M   NaN   167.0    65.0
# 3503  1998    Majid Sultan Al-Khamis   M   NaN   170.0    75.0
# 3504  1999       Khaldoun Al-Khashti   M  25.0   189.0    97.0
# 3505  2000         Mubarak Al-Khater   M  18.0   170.0    68.0
#
#                 Team  NOC        Games  Year  Season         City  \
# 0              China  CHN  1992 Summer  1992  Summer    Barcelona
# 1              China  CHN  2012 Summer  2012  Summer       London
# ...
